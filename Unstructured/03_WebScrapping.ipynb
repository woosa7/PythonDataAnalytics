# %% [markdown]
# # Web Scrap

# %% [markdown]
# ## GET

# %%
import requests

# %%
response = requests.get('http://www.naver.com')
response   # 200 = success
# Out:
# <Response [200]>

# %%
response = requests.get('http://j.mp/km-txt-slide')   # requests 라이브러리는 Redirection을 자동으로 처리한다.
response
# Out:
# <Response [200]>

# %%
response.url
# Out:
# 'https://www.dropbox.com/sh/qnbmao4x0bjnf8p/AABB3Vb2SYez9PVe6-yR0THaa?dl=0'

# %%
requests.get('http://www.seoul.go.kr/v2007/sub/error.html')    # 표준을 지키지 않는 경우 실제 없는 페이지라도 200 리턴할 수 있다.
# Out:
# <Response [200]>

# %% [markdown]
# ## Naver News

# %%
# 네이버 뉴스에서 '알파고' 뉴스 검색
response = requests.get('http://news.naver.com/main/search/search.nhn?query=%BE%CB%C6%C4%B0%ED&ie=MS949&x=0&y=0')
response
# Out:
# <Response [200]>

# %%
response.encoding = 'cp949'   # 응답의 인코딩을 cp949로 변경

# %%
response.text
# Out:
# '<!DOCTYPE HTML> \r\n<html lang="ko"> \r\n<head>\r\n<meta charset="euc-kr">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="viewport" content="width=1023" />\r\n\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n        \r\n        \r\n        \r\n        \r\n    \r\n    \r\n    \r\n    \r\n\r\n<meta property="og:title"       content="뉴스검색 : 네이버 뉴스">\r\n<meta property="og:type"        content="website">\r\n<meta property="og:url"         content="http://news.naver.com/main/search/search.nhn">\r\n<meta property="og:image"       content="http://static.news.naver.net/image/news/ogtag/navernews_200x200_20160804.png"/>\r\n<meta property="og:description" content="네이버 뉴스 검색 서비스">\r\n\r\n<meta name="twitter:card"\t\tcontent="summary">\r\n<meta name="twitter:title"\t\tcontent="뉴스검색 : 네이버 뉴스">\r\n<meta name="twitter:site"       content="네이버 뉴스">\r\n<meta name="twitter:creator"    content="네이버 뉴스">\r\n<meta name="twitter:image"\t\tcontent="http://static.news.naver.net/image/news/ogtag/navernews_200x200_20160804.png">\r\n<meta name="twitter:description" content="네이버 뉴스 검색 서비스">\r\n\r\n\r\n<title>알파고 검색결과 : 네이버 뉴스</title>\r\n<link rel="shortcut icon" type="image/x-icon" href="http://static.news.naver.net/image/news/2014/favicon/favicon.ico" />\r\n\r\n\r\n\r\n\t\r\n\t\r\n\t\r\n\r\n\r\n<!-- Sub main menu -->\r\n<style type=text/css>\r\n.search01{color:#2929D6} a.search01:link{color:#2929D6;text-decoration:underline} a.search01:visited{color:#800080;text-decoration:underline} a.search01:active{color:#2929D6F;text-decoration:underline} a.search01:hover{color:#2929D6;text-decoration:underline}\r\n.search02{color:#909090} a.search02:link{color:#909090;text-decoration:underline} a.search02:visited{color:#B2B2B2;text-decoration:underline} a.search02:active{color:#909090;text-decoration:underline} a.search02:hover{color:#CF4900;text-decoration:none}\r\n.search03{color:#2929D6} a.search03:link{color:#2929D6;text-decoration:none} a.search03:visited{color:#6A6A6A} a.search03:active{color:#2929D6F;text-decoration:underline} a.search03:hover{color:#2929D6;text-decoration:underline}\r\n</style>\r\n\r\n\t\r\n\t\t<link rel="stylesheet" type="text/css" href="http://static.news.naver.net/pnews/resources/20170310_123017/css/common.css" charset="euc-kr"/>\r\n\t\t<link rel="stylesheet" type="text/css" href="http://static.news.naver.net/pnews/resources/20170310_123017/css/news.css" charset="euc-kr"/>\r\n\t\t\r\n\t\t\r\n\t\t\r\n\t    \r\n\t\r\n\t\r\n\r\n\r\n\r\n\r\n\r\n<script type="text/javascript" src="http://static.news.naver.net/pnews/resources/20170310_123017/js/news.jindo.js" charset="euc-kr"></script>\r\n\r\n\r\n\r\n\r\n\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\r\n\t\t\r\n\t\r\n\t\t\r\n\t\r\n\r\n\r\n\r\n\t\r\n\r\n\r\n\r\n\t\r\n\r\n\r\n<script type="text/javascript">\r\ndocument.domain=\'naver.com\';\r\nvar _MAIN_NEWS_MENU_ID=\'etc\';\r\nvar _MAIN_NEWS_SECTION_ID=\'104\';\r\nvar ccsrv=\'cc.naver.com\';\r\nvar nsc=\'news.etcs\';\r\nvar gnb_service=\'news\';\r\nvar gnb_logout=\'http://news.naver.com\';\r\nvar gnb_template=\'gnb_euckr\';\r\nvar gnb_brightness = 1;\r\nvar gnb_one_naver = 1;\r\nvar gnb_searchbox=\'on\';\r\nvar gnb_shortnick=\'on\';\r\n\r\nvar gnb_timestamp = "2017031216";\r\n</script>\r\n\r\n\r\n\r\n\r\n<script type="text/javascript" src="http://static.news.naver.net/pnews/resources/20170310_123017/js/news.service.js" charset="euc-kr"></script>\r\n\r\n\r\n\r\n\r\n\r\n<script type=text/javascript>\r\nvar g_D = 0 ;\r\n\r\nfunction tt_sub_disable (o) { \r\n\tif (typeof(o.tt_sub) == "undefined") {\r\n\t\treturn false ; \r\n\t}\r\n\tif ((typeof(o.tt_sub) == "object") && (o.tt_sub.length)) { \r\n\t\tvar i ; \r\n\t\tfor (var i=0; i<o.tt_sub.length; i++) {\r\n\t\t\to.tt_sub[i].disabled = true ; \r\n\t\t}\r\n\t} else {\r\n\t\to.tt_sub.disabled = true ; \r\n\t}\r\n\treturn true ; \r\n}\r\n\r\nvar ...

# %% [markdown]
# ## HTML 처리

# %%
import lxml.html

# %%
root = lxml.html.fromstring(response.text)
root
# Out:
# <Element html at 0x1af5fd6bcc8>

# %%
for node in root.xpath('.//a[@class="tit"]'):
    print(node.text_content(), node.attrib['href'])
# Out:
# [이송렬기자의 증권이야기]'빙산의 일각' 알파고…4차 산업혁명이란? http://www.ebn.co.kr/news/view/881151
# 글로벌 IT 공룡, AI 스타트업 인수 전쟁 치열...한국은 걸음마 단계 http://biz.chosun.com/site/data/html_dir/2017/03/12/2017031200011.html
# [알파고 쇼크 1년] 구글·애플, 수년전부터 AI 공들여 아마존은 생태계 경쟁서 치고나가 http://www.sedaily.com/NewsView/1ODBUMT9VH
# (토마토칼럼)알파고 충격 1년…인류의 숙제 http://www.newstomato.com/ReadNews.aspx?no=737065
# [바둑]알파고 vs 인간 특선보… 알파고의 중앙 대접 http://news.donga.com/3/all/20170309/83255532/1
# [이번 주의 역사인물]스탠리 큐브릭과 알파고 http://view.asiae.co.kr/news/view.htm?idxno=2017031010384713726
# 알파고 1년, 일자리 논란부터 로봇세, SW교육까지 http://www.etnews.com/20170309000172
# '알파고 쇼크' 1년…AI 개척시대 열었지만 '곳곳 가시밭길' http://news1.kr/articles/?2931056
# 알파고 쇼크 1년 … 바둑 패러다임이 달라졌다 http://news.joins.com/article/olink/20943607
# [바둑]알파고 vs 인간 특선보… 너무 불확실한 투자 http://news.donga.com/3/all/20170309/83236826/1
